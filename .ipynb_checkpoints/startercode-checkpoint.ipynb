# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "outbreaks.csv"
outbreaksdf = pd.read_csv(csv_file)
outbreaksdf
# Out:
#        Year  Month       State      Primary Mode  \
# 0      2009      1   Minnesota  Person-to-person
# 1      2009      1   Minnesota              Food
# 2      2009      2   Minnesota  Person-to-person
# 3      2009      1   Minnesota  Person-to-person
# 4      2009      1   Minnesota              Food
# ...     ...    ...         ...               ...
# 46019  2017      4     Florida              Food
# 46020  2017     12     Florida              Food
# 46021  2017     12  Multistate              Food
# 46022  2017      5     Florida              Food
# 46023  2014     11     Arizona              Food
#
#                                        Etiology Serotype or Genotype  \
# 0                        Norovirus Genogroup II              unknown
# 1                                     Norovirus                  NaN
# 2                                     Norovirus                  NaN
# 3                             Norovirus unknown                  NaN
# 4                                     Norovirus                  NaN
# ...                                         ...                  ...
# 46019                    Norovirus Genogroup II                  NaN
# 46020                                       NaN                  NaN
# 46021  Salmonella enterica; Salmonella enterica   Montevideo; Cubana
# 46022                                       NaN                  NaN
# 46023    Bacillus cereus; Staphylococcus aureus                  NaN
#
#             Etiology Status                       Setting  Illnesses  \
# 0                 Confirmed                   Hotel/motel         21
# 1                 Suspected  Restaurant - Sit-down dining          2
# 2                 Suspected                Other, specify         50
# 3                 Confirmed                    Restaurant         24
# 4                 Confirmed                           NaN         16
# ...                     ...                           ...        ...
# 46019             Confirmed  Restaurant - Sit-down dining         10
# 46020                   NaN  Restaurant - Sit-down dining          4
# 46021  Confirmed; Confirmed                       Unknown         62
# 46022                   NaN  Restaurant - Sit-down dining         10
# 46023  Suspected; Suspected                       Unknown         65
#
#        Hospitalizations  ...  Deaths  Info on Deaths  \
# 0                   0.0  ...     0.0            19.0
# 1                   0.0  ...     0.0             2.0
# 2                   0.0  ...     0.0            50.0
# 3                   0.0  ...     0.0            24.0
# 4                   0.0  ...     0.0            16.0
# ...                 ...  ...     ...             ...
# 46019               0.0  ...     0.0            10.0
# 46020               0.0  ...     0.0             4.0
# 46021               3.0  ...     0.0            51.0
# 46022               0.0  ...     0.0            10.0
# 46023               1.0  ...     0.0            65.0
#
#                                             Food Vehicle  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 46019                                                NaN
# 46020                                                NaN
# 46021                                            sprouts
# 46022                                           fish dip
# 46023  meat chili; potato salad; beans, unspecified; ...
#
#       Food Contaminated Ingredient IFSAC Category Water Exposure Water Type  \
# 0                              NaN            NaN            NaN        NaN
# 1                              NaN            NaN            NaN        NaN
# 2                              NaN            NaN            NaN        NaN
# 3                              NaN            NaN            NaN        NaN
# 4                              NaN            NaN            NaN        NaN
# ...                            ...            ...            ...        ...
# 46019                          NaN            NaN            NaN        NaN
# 46020                          NaN            NaN            NaN        NaN
# 46021                          NaN        Sprouts            NaN        NaN
# 46022                          NaN       Multiple            NaN        NaN
# 46023                          NaN       Multiple            NaN        NaN
#
#       Animal Type Animal Type Specify Water Status
# 0             NaN                 NaN          NaN
# 1             NaN                 NaN          NaN
# 2             NaN                 NaN          NaN
# 3             NaN                 NaN          NaN
# 4             NaN                 NaN          NaN
# ...           ...                 ...          ...
# 46019         NaN                 NaN          NaN
# 46020         NaN                 NaN          NaN
# 46021         NaN                 NaN          NaN
# 46022         NaN                 NaN          NaN
# 46023         NaN                 NaN          NaN
#
# [46024 rows x 21 columns]

# %%
obdf = outbreaksdf[['Year', 'State', 'Primary Mode', 'Etiology', 'Setting','Illnesses']].copy()
obdf = obdf.rename(columns={"Year": "year","State": "stateid", "Primary Mode": "primarymode", "Etiology": "etiology", 'Setting':'setting',"Illnesses": "illness"})

obdf
# Out:
#        year     stateid       primarymode  \
# 0      2009   Minnesota  Person-to-person
# 1      2009   Minnesota              Food
# 2      2009   Minnesota  Person-to-person
# 3      2009   Minnesota  Person-to-person
# 4      2009   Minnesota              Food
# ...     ...         ...               ...
# 46019  2017     Florida              Food
# 46020  2017     Florida              Food
# 46021  2017  Multistate              Food
# 46022  2017     Florida              Food
# 46023  2014     Arizona              Food
#
#                                        etiology                       setting  \
# 0                        Norovirus Genogroup II                   Hotel/motel
# 1                                     Norovirus  Restaurant - Sit-down dining
# 2                                     Norovirus                Other, specify
# 3                             Norovirus unknown                    Restaurant
# 4                                     Norovirus                           NaN
# ...                                         ...                           ...
# 46019                    Norovirus Genogroup II  Restaurant - Sit-down dining
# 46020                                       NaN  Restaurant - Sit-down dining
# 46021  Salmonella enterica; Salmonella enterica                       Unknown
# 46022                                       NaN  Restaurant - Sit-down dining
# 46023    Bacillus cereus; Staphylococcus aureus                       Unknown
#
#        illness
# 0           21
# 1            2
# 2           50
# 3           24
# 4           16
# ...        ...
# 46019       10
# 46020        4
# 46021       62
# 46022       10
# 46023       65
#
# [46024 rows x 6 columns]

# %%
csv_file = "UnderlyingCauseofDeath19992017.csv"
coddf = pd.read_csv(csv_file)

# %%
coddf = coddf[['State', 'Cause of death', 'Deaths', 'Population']].copy()
coddf = coddf.rename(columns={"State": "stateid", "Cause of death": "cause", "Deaths": "deaths", "Population": "population"})
coddf
# Out:
#          stateid                                              cause  deaths  \
# 0        Alabama         Enterocolitis due to Clostridium difficile     273
# 1        Alabama  Gastroenteritis and colitis of unspecified origin      92
# 2        Alabama                  Pulmonary mycobacterial infection      11
# 3        Alabama           Septicaemia due to Staphylococcus aureus      30
# 4        Alabama      Septicaemia due to unspecified staphylococcus      12
# ...          ...                                                ...     ...
# 26698  Wisconsin     Legal intervention involving firearm discharge      10
# 26699  Wisconsin                           Other medical procedures      16
# 26700  Wisconsin                 Sequelae of motor-vehicle accident      54
# 26701  Wisconsin                        Sequelae of other accidents      72
# 26702  Wisconsin                                Sequelae of assault      12
#
#        population
# 0         7840781
# 1         7840781
# 2         7840781
# 3         7840781
# 4         7840781
# ...           ...
# 26698    12725772
# 26699    12725772
# 26700    12725772
# 26701    12725772
# 26702    12725772
#
# [26703 rows x 4 columns]

# %%
rds_connection_string = "postgres:password@localhost:5432/IllestDB"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['death', 'outbreak']

# %%
obdf.to_sql(name='outbreak', con=engine, if_exists='append', index=False)

# %%
coddf.to_sql(name='death', con=engine, if_exists='append', index=False)
