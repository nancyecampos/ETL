# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "deathsCSV.csv"
deathsdf = pd.read_csv(csv_file)
deathsdf.head()
# Out:
#     geoid  Region          State  age   season  MMWR Year/Week  \
# 0   State     NaN  New Hampshire  All  2017-18          201805
# 1   State     NaN  New York City  All  2015-16          201629
# 2   State     NaN       Missouri  All  2009-10          201020
# 3  Region     3.0            NaN  All  2010-11          201134
# 4   State     NaN         Kansas  All  2017-18          201820
#
#    Deaths from influenza  Deaths from pneumonia  \
# 0                    NaN                    NaN
# 1                    NaN                    NaN
# 2                    NaN                    NaN
# 3                    0.0                  280.0
# 4                    NaN                    NaN
#
#    Deaths from pneumonia and influenza  All Deaths  \
# 0                                 28.0       286.0
# 1                                 64.0       972.0
# 2                                 84.0       984.0
# 3                                280.0      4662.0
# ...

# %%
csv_file = "outbreaks.csv"
outbreaksdf = pd.read_csv(csv_file)
outbreaksdf
# Out:
#        Year  Month       State      Primary Mode  \
# 0      2009      1   Minnesota  Person-to-person
# 1      2009      1   Minnesota              Food
# 2      2009      2   Minnesota  Person-to-person
# 3      2009      1   Minnesota  Person-to-person
# 4      2009      1   Minnesota              Food
# ...     ...    ...         ...               ...
# 46019  2017      4     Florida              Food
# 46020  2017     12     Florida              Food
# 46021  2017     12  Multistate              Food
# 46022  2017      5     Florida              Food
# 46023  2014     11     Arizona              Food
#
#                                        Etiology Serotype or Genotype  \
# 0                        Norovirus Genogroup II              unknown
# 1                                     Norovirus                  NaN
# 2                                     Norovirus                  NaN
# 3                             Norovirus unknown                  NaN
# ...

# %%
obdf = outbreaksdf[['Year', 'Month', 'State', 'Primary Mode', 'Etiology', 'Illnesses']].copy()
obdf
# Out:
#        Year  Month       State      Primary Mode  \
# 0      2009      1   Minnesota  Person-to-person
# 1      2009      1   Minnesota              Food
# 2      2009      2   Minnesota  Person-to-person
# 3      2009      1   Minnesota  Person-to-person
# 4      2009      1   Minnesota              Food
# ...     ...    ...         ...               ...
# 46019  2017      4     Florida              Food
# 46020  2017     12     Florida              Food
# 46021  2017     12  Multistate              Food
# 46022  2017      5     Florida              Food
# 46023  2014     11     Arizona              Food
#
#                                        Etiology  Illnesses
# 0                        Norovirus Genogroup II         21
# 1                                     Norovirus          2
# 2                                     Norovirus         50
# 3                             Norovirus unknown         24
# 4                                     Norovirus         16
# ...
